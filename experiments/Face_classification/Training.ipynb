# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
# from keras.preprocessing.image import ImageDataGenerator
# Out:
# C:\Users\Goutham\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np
import glob
from PIL import Image
import pickle
import os

# %%
class Classify_Gender(object):

    def __init__(self, model_name, input_shape):
        self.nClasses = 2
        if model_name != None:
            self.model = load_model(location, model_name)
        else:
            self.model = self.createModel(input_shape)
            
    def createModel(self, input_shape):
        model = Sequential()
        model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
        model.add(Conv2D(32, (3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
        model.add(Conv2D(64, (3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
        model.add(Conv2D(64, (3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        model.add(Flatten())
        model.add(Dense(512, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(self.nClasses, activation='softmax'))
        return model

    def train(self,train_data, train_labels, test_data, test_labels, batch_size = 250, epochs = 100):
        try:    
            self.model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

            history = self.model.fit(train_data, train_labels, batch_size=batch_size, epochs=epochs, verbose=1,
                               validation_data=(test_data, test_labels))
            print(history)
            return True
        except Exception as e:
            print(e)
            return False

    def predict(self, test_data, test_labels, retrain = True):
        temp_data = []
        if retrain and type(test_data) != "numpy.array.array":
            for data in test_data:
                temp_data.append(np.asarray(data))
                print("Testing for data\n", data)
                return self.model.evaluate(data, test_labels)
        else:
            print("Not retraining data to the model")
            return self.model.evaluate(test_data, test_labels)


    def save_model(self, model_name, save_location):
        if os.path.exists(save_location):
            try:
                with open(save_location + '/' + model_name) as f:
                    pickle.dump(self.model, f)
                    print("Model Saved as", model_name, "in", "save_location")
                    return True
            except Exception as e:
                print(e)
                return False
        else:
            print("Failed to save Model")
            return False


    def load_model(self, location, model_name):
        with open(location + "/" + model_name) as f:
            model = pickle.load(f)
            print("Model Loaded Successfully")
        return model

    def load_training_data(location):
        train_data = []
        if location != None:
            for image in glob.glob(location):
                temp_image = Image.load(image)
                train_data = np.asarray(train_data)
        print(len(train_data))


    def plot_out(self):
        plt.figure(figsize=[8,6])
        plt.plot(history.history['loss'],'r',linewidth=3.0)
        plt.plot(history.history['val_loss'],'b',linewidth=3.0)
        plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
        plt.xlabel('Epochs ',fontsize=16)
        plt.ylabel('Loss',fontsize=16)
        plt.title('Loss Curves',fontsize=16)

        # Accuracy Curves
        plt.figure(figsize=[8,6])
        plt.plot(history.history['acc'],'r',linewidth=3.0)
        plt.plot(history.history['val_acc'],'b',linewidth=3.0)
        plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
        plt.xlabel('Epochs ',fontsize=16)
        plt.ylabel('Accuracy',fontsize=16)
        plt.title('Accuracy Curves',fontsize=16)

# %%
train_X = []
train_Y = []

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-118-72fbbcfe2587> in <module>()
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
def load_training_data(location, labelfile1, labelfile2):
    train_data = []
    train_labels = []
    males = open(labelfile1).readlines()[:250]
    females = open(labelfile2).readlines()[:250]
#     print(type(males))
    if location != None:
        for image in males:
            image = image.replace("\n", "")
            print("Working on", image)
            imagename = location + image
            temp_image = np.array(Image.open(imagename))
            
            train_data.append(temp_image)
            
            train_labels.append([1, 0])
        for image in females:
            image = image.replace("\n", "")
            print("Working on", image)
            imagename = location + image
i_nf_nc_hp_2014_1_e0_nl_o.jpg
# Working on HadM_00818_f_25_o_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on HadM_00819_f_25_o_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on HebD_00821_f_28_i_nf_cr_sd_2016_1_e0_nl_o.jpg
# Working on HebD_00822_f_28_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on JakN_00861_f_22_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on LalG_00881_f_2_o_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on MalA_01276_f_3_i_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MalA_01277_f_3_i_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on MalA_01278_f_3_i_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on MalA_01279_f_3_i_fr_nc_sd_2016_1_e0_nl_o.jpg
# Working on MalA_01280_f_3_i_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MalA_01281_f_3_o_fr_nc_no_2016_1_e0_nl_o.jpg
# Working on MalA_01282_f_3_i_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on MalA_01283_f_3_i_nf_nc_sd_2016_1_e0_nl_o.jpg
# Working on MarE_01284_f_20_i_fr_cr_sd_2015_1_e0_nl_o.jpg
# Working on MarE_01285_f_21_o_nf_cr_no_2016_1_e0_nl_o.jpg
# Working on MarG_01286_f_20_o_nf_nc_sr_2016_1_e0_nl_o.jpg
# Working on MarG_01287_f_20_o_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on MarG_01288_f_20_o_nf_cr_no_2016_1_e0_nl_o.jpg
# Working on MarG_01289_f_20_i_nf_nc_sd_2016_1_e0_nl_o.jpg
# Working on MarG_01290_f_20_o_fr_cr_no_2016_1_e0_nl_o.jpg
# Working on MarG_01291_f_20_i_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on MarG_01292_f_20_o_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on MarG_01293_f_20_o_fr_nc_no_2016_1_e0_nl_o.jpg
# Working on MarG_01294_f_20_o_nf_nc_sr_2016_1_e0_nl_o.jpg
# Working on MarG_01295_f_19_o_nf_nc_sd_2015_1_e0_nl_o.jpg
# Working on MarG_01296_f_19_i_nf_nc_sd_2015_1_e0_nl_o.jpg
# Working on MarG_01297_f_18_i_fr_nc_sd_2014_1_e0_nl_o.jpg
# Working on MarG_01298_f_20_o_nf_nc_no_2016_1_e0_nl_o.jpg
# Working on MarH_01299_f_31_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarH_01300_f_31_o_fr_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarH_01301_f_31_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarH_01302_f_27_o_nf_nc_hp_2012_1_e0_nl_o.jpg
# Working on MarH_01303_f_26_i_nf_nc_hp_2011_1_e0_nl_o.jpg
# Working on MarH_01304_f_27_o_nf_nc_hp_2012_1_e0_nl_o.jpg
# Working on MarM_01305_f_21_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarM_01306_f_21_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarM_01307_f_21_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarM_01308_f_21_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarM_01309_f_21_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarS_01322_f_29_i_fr_nc_hp_2016_1_e0_nl_o.jpg
# Working on MarS_01323_f_29_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MayA_01324_f_9_i_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MayA_01325_f_9_i_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MayA_01326_f_9_i_fr_nc_hp_2016_1_e0_nl_o.jpg
# Working on MeiH_01351_f_20_i_fr_nc_no_2015_1_e0_nl_o.jpg
# Working on MeiH_01352_f_20_i_fr_nc_sd_2015_1_e0_nl_o.jpg
# Working on MeiH_01353_f_20_i_fr_nc_hp_2015_1_e0_nl_o.jpg
# Working on MeiH_01354_f_20_i_fr_nc_hp_2015_1_e0_nl_o.jpg
# Working on MeiH_01355_f_20_i_fr_nc_no_2015_1_e0_nl_o.jpg
# Working on MeiH_01356_f_20_i_nf_nc_sd_2015_1_e0_nl_o.jpg
# Working on MeiH_01357_f_20_i_fr_nc_hp_2015_1_e0_nl_o.jpg
# Working on MeiH_01358_f_20_i_fr_nc_hp_2015_1_e0_nl_o.jpg
# Working on MeiH_01359_f_20_i_fr_cr_no_2015_1_e0_nl_o.jpg
# Working on MeiH_01360_f_20_i_nf_nc_sd_2015_1_e0_nl_o.jpg
# Working on MeiH_01361_f_20_i_fr_nc_hp_2015_1_e0_nl_o.jpg
# Working on MeiH_01362_f_20_i_fr_nc_hp_2015_1_e0_nl_o.jpg
# Working on MeiH_01363_f_20_i_fr_nc_no_2015_1_e0_nl_o.jpg
# Working on MeiH_01364_f_20_i_fr_nc_no_2015_1_e0_nl_o.jpg
# Working on MeiH_01365_f_20_i_fr_nc_hp_2015_1_e0_nl_o.jpg
# Working on MeiH_01366_f_20_i_fr_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerB_01367_f_20_o_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerD_01368_f_21_o_fr_nc_hp_2016_1_e0_nl_o.jpg
# Working on MerD_01369_f_21_o_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MerK_01370_f_20_o_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01371_f_20_o_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01372_f_20_o_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01373_f_20_i_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01374_f_20_i_nf_nc_sr_2015_1_e0_nl_o.jpg
# Working on MerK_01375_f_20_i_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01376_f_20_i_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01377_f_20_o_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01378_f_20_o_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01379_f_20_o_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01380_f_20_i_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01381_f_20_i_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01382_f_20_i_nf_nc_sr_2015_1_e0_nl_o.jpg
# Working on MerK_01383_f_20_i_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01384_f_20_o_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01385_f_20_o_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01386_f_20_o_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01387_f_20_i_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01388_f_20_i_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01389_f_20_i_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01390_f_20_i_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01391_f_20_o_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01392_f_20_i_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01393_f_20_i_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01394_f_20_i_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerK_01395_f_20_i_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01396_f_20_o_nf_nc_hp_2015_1_e0_nl_o.jpg
# Working on MerK_01397_f_20_o_nf_nc_no_2015_1_e0_nl_o.jpg
# Working on MerM_01398_f_20_i_nf_nc_hp_2016_1_e0_nl_o.jpg
# Working on MerM_01399_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01400_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01401_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01402_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01403_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01404_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01405_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01406_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01407_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01408_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01409_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01410_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01411_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01412_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01413_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01414_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01415_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01416_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01417_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01418_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01419_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01420_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01421_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01422_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01423_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01424_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01425_f_20_i_nf_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01426_f_20_i_nf_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01427_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01428_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01429_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01430_f_20_i_nf_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01431_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01432_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01433_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01434_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01435_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01436_f_20_i_nf_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01437_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01438_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01439_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01440_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01441_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01442_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01443_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01444_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01445_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01446_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01447_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01448_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01449_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01450_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01451_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01452_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01453_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01454_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01455_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01456_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01457_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01458_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01459_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01460_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01461_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01462_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01463_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01464_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01465_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01466_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01467_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01468_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01469_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01470_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01471_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01472_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01473_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Working on MerM_01474_f_20_i_nf_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01475_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01476_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01477_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01478_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01479_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01480_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01481_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01482_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01483_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01484_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01485_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01486_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01487_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01488_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01489_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01490_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01491_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01492_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01493_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01494_f_20_i_fr_nc_hp_2016_2_e0_nl_o.jpg
# Working on MerM_01495_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01496_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01497_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01498_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01499_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01500_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01501_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01502_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01503_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01504_f_20_i_fr_nc_sr_2016_2_e0_nl_o.jpg
# Working on MerM_01505_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01506_f_20_i_fr_nc_no_2016_2_e0_nl_o.jpg
# Working on MerM_01507_f_20_i_fr_nc_sd_2016_2_e0_nl_o.jpg
# Shape is  (480, 640, 3)

# %%
print(len(train_X), len(train_Y))
# Out:
# 2662 2662

# %%
train_X[0]
# Out:
# array([[[ 97, 221, 159],
#         [ 97, 221, 159],
#         [ 98, 222, 160],
#         ...,
#         [120, 235, 178],
#         [120, 235, 178],
#         [120, 235, 178]],
#
#        [[ 97, 221, 159],
#         [ 97, 221, 159],
#         [ 98, 222, 160],
#         ...,
#         [121, 236, 179],
#         [120, 235, 178],
#         [120, 235, 178]],
#
#        [[ 97, 221, 159],
#         [ 97, 221, 159],
#         [ 98, 222, 160],
#         ...,
#         [121, 236, 179],
#         [121, 236, 179],
#         [120, 235, 178]],
#
#        ...,
#
#        [[ 96, 220, 157],
#         [ 97, 221, 158],
#         [ 97, 221, 158],
#         ...,
#         [102, 225, 162],
#         [102, 225, 162],
#         [102, 225, 162]],
#
#        [[ 96, 220, 157],
#         [ 96, 220, 157],
#         [ 97, 221, 158],
#         ...,
#         [102, 225, 162],
#         [101, 224, 161],
#         [101, 224, 161]],
#
#        [[ 96, 220, 157],
#         [ 96, 220, 157],
#         [ 96, 220, 157],
#         ...,
#         [101, 224, 161],
#         [101, 224, 161],
#         [101, 224, 161]]], dtype=uint8)

# %%
train_X[0].shape
# Out:
# (480, 640, 3)

# %%
c = Classify_Gender(None, train_X[0].shape)

# %%
c.train(train_X, train_Y, train_X, train_Y)
# Out:
# Train on 500 samples, validate on 500 samples
# Epoch 1/100
